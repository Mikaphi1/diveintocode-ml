# %% [markdown]
# #**Problem 1**
# ##*Data acquisition*

# %%
from sklearn.datasets import load_iris
data = load_iris()
import pandas as pd
X = pd.DataFrame(data.data, columns=data.feature_names)
X
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
Y = pd.DataFrame(data.target, columns=["Species"])
Y
# Out:
#      Species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2
#
# [150 rows x 1 columns]

# %% [markdown]
# #**Problem 2**
# ##*Combining data*

# %%
df = pd. concat([X,Y], axis=1)
df
# Out:
#      sepal length (cm)  sepal width (cm)  ...  petal width (cm)  Species
# 0                  5.1               3.5  ...               0.2        0
# 1                  4.9               3.0  ...               0.2        0
# 2                  4.7               3.2  ...               0.2        0
# 3                  4.6               3.1  ...               0.2        0
# 4                  5.0               3.6  ...               0.2        0
# ..                 ...               ...  ...               ...      ...
# 145                6.7               3.0  ...               2.3        2
# 146                6.3               2.5  ...               1.9        2
# 147                6.5               3.0  ...               2.0        2
# 148                6.2               3.4  ...               2.3        2
# 149                5.9               3.0  ...               1.8        2
#
# [150 rows x 5 columns]

# %% [markdown]
# #**Problem 3**
# ##*Checking the data*

# %% [markdown]
# #####Display the 4th sample from the beginning and see what each feature is like. (Numerical data or character data, etc.)

# %%
#NOTE: the index of the 4th sample is 3.

#using .loc[]
df.iloc[[3]]
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  Species
# 3                4.6               3.1  ...               0.2        0
#
# [1 rows x 5 columns]

# %%
#using .head()
print(df.head(4))
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  Species
# 0                5.1               3.5  ...               0.2        0
# 1                4.9               3.0  ...               0.2        0
# 2                4.7               3.2  ...               0.2        0
# 3                4.6               3.1  ...               0.2        0
#
# [4 rows x 5 columns]

# %% [markdown]
# #####Output the total number of samples for each label.

# %%
print(df['Species'].value_counts())
# Out:
# 2    50
# 1    50
# 0    50
# Name: Species, dtype: int64

# %% [markdown]
# #####Check if there is a missing value in the feature quantity.

# %%
#using .isnull()
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# Species              0
# dtype: int64

# %%
#using .info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   Species            150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %% [markdown]
# #####Display the mean, standard deviation, and quartiles of the feature values at once

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  ...  petal width (cm)     Species
# count         150.000000        150.000000  ...        150.000000  150.000000
# mean            5.843333          3.057333  ...          1.199333    1.000000
# std             0.828066          0.435866  ...          0.762238    0.819232
# min             4.300000          2.000000  ...          0.100000    0.000000
# 25%             5.100000          2.800000  ...          0.300000    0.000000
# 50%             5.800000          3.000000  ...          1.300000    1.000000
# 75%             6.400000          3.300000  ...          1.800000    2.000000
# max             7.900000          4.400000  ...          2.500000    2.000000
#
# [8 rows x 5 columns]

# %% [markdown]
# #**Problem 4**
# ##*Examining the iris dataset itself*

# %% [markdown]
# The famous Iris database, first used by Sir R.A. Fisher. The dataset is taken from Fisher’s paper. Note that it’s the same as in R, but not as in the UCI Machine Learning Repository, which has two wrong data points.
#
# This is perhaps the best known database to be found in the pattern recognition literature. Fisher’s paper is a classic in the field and is referenced frequently to this day. (See Duda & Hart, for example.) The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant. One class is linearly separable from the other 2; the latter are NOT linearly separable from each other
#
# https://scikit-learn.org/stable/datasets/toy_dataset.html#iris-dataset

# %% [markdown]
# #**Problem 5**
# ##*Extracting the required data*

# %% [markdown]
# #####Extract sepal_width columns in three different ways

# %%
# Method 1
sepal_width = pd.DataFrame(df.iloc[:,1])
sepal_width
# Out:
#      sepal width (cm)
# 0                 3.5
# 1                 3.0
# 2                 3.2
# 3                 3.1
# 4                 3.6
# ..                ...
# 145               3.0
# 146               2.5
# 147               3.0
# 148               3.4
# 149               3.0
#
# [150 rows x 1 columns]

# %%
# Method 2
sepal_width2 = pd.DataFrame(df.loc['0':'9','sepal width (cm)'])
sepal_width2
# Out:
#      sepal width (cm)
# 0                 3.5
# 1                 3.0
# 2                 3.2
# 3                 3.1
# 4                 3.6
# ..                ...
# 145               3.0
# 146               2.5
# 147               3.0
# 148               3.4
# 149               3.0
#
# [150 rows x 1 columns]

# %%
# Method 3
sepal_width3 = pd.DataFrame(df['sepal width (cm)'])
sepal_width3
# Out:
#      sepal width (cm)
# 0                 3.5
# 1                 3.0
# 2                 3.2
# 3                 3.1
# 4                 3.6
# ..                ...
# 145               3.0
# 146               2.5
# 147               3.0
# 148               3.4
# 149               3.0
#
# [150 rows x 1 columns]

# %% [markdown]
# Extract the 50th to 99th data​

# %%
fifty_to_ninety = df.iloc[50:100]
fifty_to_ninety
# Out:
#     sepal length (cm)  sepal width (cm)  ...  petal width (cm)  Species
# 50                7.0               3.2  ...               1.4        1
# 51                6.4               3.2  ...               1.5        1
# 52                6.9               3.1  ...               1.5        1
# 53                5.5               2.3  ...               1.3        1
# 54                6.5               2.8  ...               1.5        1
# 55                5.7               2.8  ...               1.3        1
# 56                6.3               3.3  ...               1.6        1
# 57                4.9               2.4  ...               1.0        1
# 58                6.6               2.9  ...               1.3        1
# 59                5.2               2.7  ...               1.4        1
# 60                5.0               2.0  ...               1.0        1
# 61                5.9               3.0  ...               1.5        1
# ...

# %% [markdown]
# Extract the 50th to 99th data of the petal_length column

# %%
fifty_to_ninety_petal_lenth = pd.DataFrame(df['petal length (cm)'].iloc[50:100])
fifty_to_ninety_petal_lenth
# Out:
#     petal length (cm)
# 50                4.7
# 51                4.5
# 52                4.9
# 53                4.0
# 54                4.6
# 55                4.5
# 56                4.7
# 57                3.3
# 58                4.6
# 59                3.9
# 60                3.5
# 61                4.2
# 62                4.0
# 63                4.7
# 64                3.6
# 65                4.4
# 66                4.5
# 67                4.1
# 68                4.5
# 69                3.9
# 70                4.8
# 71                4.0
# 72                4.9
# 73                4.7
# 74                4.3
# 75                4.4
# 76                4.8
# 77                5.0
# 78                4.5
# 79                3.5
# 80                3.8
# 81                3.7
# 82                3.9
# 83                5.1
# 84                4.5
# 85                4.5
# 86                4.7
# 87                4.4
# 88                4.1
# 89                4.0
# ...

# %% [markdown]
# Extract data with a petal_width value of 0.2​

# %%
pw_greaterthan = df[df['petal width (cm)'] == 0.2]
pw_greaterthan
# Out:
#     sepal length (cm)  sepal width (cm)  ...  petal width (cm)  Species
# 0                 5.1               3.5  ...               0.2        0
# 1                 4.9               3.0  ...               0.2        0
# 2                 4.7               3.2  ...               0.2        0
# 3                 4.6               3.1  ...               0.2        0
# 4                 5.0               3.6  ...               0.2        0
# 7                 5.0               3.4  ...               0.2        0
# 8                 4.4               2.9  ...               0.2        0
# 10                5.4               3.7  ...               0.2        0
# 11                4.8               3.4  ...               0.2        0
# 14                5.8               4.0  ...               0.2        0
# 20                5.4               3.4  ...               0.2        0
# 22                4.6               3.6  ...               0.2        0
# ...

# %% [markdown]
# ###Differences between loc and iloc
# The main difference between loc and iloc is that **loc** is label-based, which means that you have to specify rows and columns based on their row and column labels, while **iloc**  is integer position-based, so you have to specify rows and columns by their integer position values (0-based integer position)

# %% [markdown]
# #**Problem 6**
# ##*Creating a diagram*

# %%
#Pie chart
import matplotlib.pyplot as plt
# %matplotlib inline

labels = 'Iris-Setosa', 'Iris-Versicolour', 'Iris-Virginica'
number_of_samples = list(df['Species'].value_counts())
explode = (0, 0, 0)  #no label exploded

fig1, ax1 = plt.subplots()
ax1.pie(number_of_samples, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
#boxplots
df.loc[df["Species"]==0]
# Out:
#     sepal length (cm)  sepal width (cm)  ...  petal width (cm)  Species
# 0                 5.1               3.5  ...               0.2        0
# 1                 4.9               3.0  ...               0.2        0
# 2                 4.7               3.2  ...               0.2        0
# 3                 4.6               3.1  ...               0.2        0
# 4                 5.0               3.6  ...               0.2        0
# 5                 5.4               3.9  ...               0.4        0
# 6                 4.6               3.4  ...               0.3        0
# 7                 5.0               3.4  ...               0.2        0
# 8                 4.4               2.9  ...               0.2        0
# 9                 4.9               3.1  ...               0.1        0
# 10                5.4               3.7  ...               0.2        0
# 11                4.8               3.4  ...               0.2        0
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
df.boxplot(column='sepal length (cm)', by='Species');
df.boxplot(column='sepal width (cm)', by='Species');
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %%
import seaborn as sns
#using seaborn boxplot
sns.boxplot(x='Species', y='petal length (cm)',data=df);

# %%
sns.boxplot(x='Species', y='petal width (cm)',data=df);

# %%
sns.violinplot(x='Species', y='sepal length (cm)',data=df);

# %%
sns.violinplot(x='Species', y='sepal width (cm)',data=df);

# %%
sns.violinplot(x='Species', y='petal length (cm)',data=df);

# %%
sns.violinplot(x='Species', y='petal width (cm)',data=df);

# %% [markdown]
# #**Problem 7**
# ##*Confirming the relationship between features*

# %%
#Create a scatterplot matrix that displays all combinations of features at once.
sns.pairplot(df, hue="Species");

# %%
#Create a correlation coefficient matrix for 4 features
df.corr()
# Out:
#                    sepal length (cm)  ...   Species
# sepal length (cm)           1.000000  ...  0.782561
# sepal width (cm)           -0.117570  ... -0.426658
# petal length (cm)           0.871754  ...  0.949035
# petal width (cm)            0.817941  ...  0.956547
# Species                     0.782561  ...  1.000000
#
# [5 rows x 5 columns]

# %%
#Make a heat map of the correlation coefficient matrix (1)
sns.heatmap(df.corr()); #to view correlations using heatmap visualisation

# %% [markdown]
# #**Problem 8**
# ##*Explaining the results*
#
# The following can be deduced from the correlation analyses of the data:
# <p>There are significantly high positive correlations between petal width and petal length (of about 0.96), petal length and sepal length (0.87), and petal width and sepal length (0.82)
#
# <p>Based on the scatterplot and chart analysis, it is much easier to distinguish the the Iris species using the the petal variables than the sepal variables. Furthermore, the Iris Setosa species is easier to distinguish among the three.
